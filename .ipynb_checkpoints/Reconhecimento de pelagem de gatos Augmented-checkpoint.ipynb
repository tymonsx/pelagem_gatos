# %%
import numpy as np
import cv2
import tensorflow as tf
import os
import sklearn as sk
import sklearn.model_selection
from imutils import paths
from skimage import io
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten

tf.__version__
# Out:
# '2.1.0'

# %%
#INIT_LR = 1e-3
#EPOCHS = 10
#BS = 8
dataset = "C:/Users/User/Documents/python/pelagem_gatos/imagens"
dataset
# Out:
# 'C:/Users/User/Documents/python/pelagem_gatos/imagens'

# %%
args={}
args["dataset"]=dataset
args
# Out:
# {'dataset': 'C:/Users/User/Documents/python/pelagem_gatos/imagens'}

# %%
iPaths = list(paths.list_images(args["dataset"]))  #image paths
data = []
labels = []
for iPath in iPaths:    
    label = iPath.split(os.path.sep)[-2]   #split the image paths
    image = io.imread(iPath, True)#cv2.imread(iPath)
    #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) #Convert images into RGB Channel
    image = cv2.resize(image, (100, 100))  #Resizing the images
    image = image[..., np.newaxis]
    data.append(image)
    labels.append(label)


data = np.array(data) / 255.0
labels = np.array(labels)
labels
# Out:
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:764: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 35520512 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 18481152 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 19988480 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:764: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 10.
#   warnings.warn(str(msg))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 15728640 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 478655462 bytes but only got 0. Skipping tag 34464
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 15335424 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 15859712 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 65536 bytes but only got 0. Skipping tag 3
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 6553600 bytes but only got 0. Skipping tag 3
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 3368026112 bytes but only got 0. Skipping tag 7
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 19005440 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 19529728 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 20054016 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 20578304 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 21102592 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 21626880 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 22151168 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 327680 bytes but only got 0. Skipping tag 3
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 1048576 bytes but only got 0. Skipping tag 3
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 22675456 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 92798976 bytes but only got 0. Skipping tag 2
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 93847552 bytes but only got 0. Skipping tag 2
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 94896128 bytes but only got 0. Skipping tag 2
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 4294901760 bytes but only got 0. Skipping tag 3
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 58982400 bytes but only got 0. Skipping tag 3
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 39321600 bytes but only got 0. Skipping tag 3
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 23986176 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 24510464 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 131072 bytes but only got 0. Skipping tag 3
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 25034752 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:764: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 0.
#   warnings.warn(str(msg))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 19660800 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:747: UserWarning: Possibly corrupt EXIF data.  Expecting to read 787528 bytes but only got 953. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\User\anaconda3\envs\gatos-gpu\lib\site-packages\PIL\TiffImagePlugin.py:764: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 8.
#   warnings.warn(str(msg))
# array(['bicolor', 'bicolor', 'bicolor', ..., 'tortoiseshell',
#        'tortoiseshell', 'tortoiseshell'], dtype='<U14')

# %%
data
# Out:
# array([[[[1.54271282e-03],
#          [1.54724509e-03],
#          [1.19286213e-03],
#          ...,
#          [5.77200754e-04],
#          [9.73725675e-04],
#          [1.05076905e-03]],
#
#         [[1.19376056e-03],
#          [1.40276509e-03],
#          [1.11617378e-03],
#          ...,
#          [6.93116870e-04],
#          [1.04279566e-03],
#          [1.15297908e-03]],
#
#         [[9.79894239e-04],
#          [1.25237727e-03],
#          [1.04744883e-03],
#          ...,
#          [7.40180546e-04],
#          [1.06613272e-03],
#          [1.01196637e-03]],
#
#         ...,
#
#         [[1.57024191e-04],
#          [7.35228850e-04],
#          [7.58363783e-04],
#          ...,
#          [1.54101538e-04],
#          [2.64202845e-04],
#          [4.06809535e-04]],
#
#         [[6.91168689e-04],
#          [9.18889147e-04],
#          [8.39648328e-04],
#          ...,
#          [3.18302079e-04],
#          [2.29461023e-04],
#          [2.56210489e-04]],
#
#         [[5.29663823e-04],
#          [8.68943778e-04],
#          [7.26768166e-04],
#          ...,
#          [5.27020085e-04],
#          [4.35025990e-04],
#          [6.81002480e-04]]],
#
#
#        [[[3.65195140e-04],
#          [2.75352772e-04],
#          [2.79846213e-04],
#          ...,
#          [8.26557416e-04],
#          [7.19112649e-04],
#          [7.71677047e-04]],
#
#         [[2.91237216e-04],
#          [3.04093810e-04],
#          [3.40284506e-04],
#          ...,
#          [7.13065744e-04],
#          [7.97267205e-04],
#          [7.31138793e-04]],
#
#         [[2.96404460e-04],
#          [2.85024221e-04],
#          [2.49550173e-04],
#          ...,
#          [6.96659592e-04],
#          [7.42149942e-04],
#          [7.91054210e-04]],
#
#         ...,
#
#         [[2.44199923e-04],
#          [2.77879277e-04],
#          [3.76911957e-04],
#          ...,
#          [1.00930565e-04],
#          [1.18934256e-04],
#          [9.43283353e-05]],
#
#         [[3.29459439e-04],
#          [3.77256440e-04],
#          [2.92790465e-04],
#          ...,
#          [1.32159938e-04],
#          [1.98306805e-04],
#          [1.47280277e-04]],
#
#         [[3.47575548e-04],
#          [2.36079969e-04],
#          [2.52968304e-04],
#          ...,
#          [1.98262207e-04],
#          [2.37874664e-04],
#          [1.87340254e-04]]],
#
#
#        [[[2.78230834e-03],
#          [2.79282737e-03],
#          [2.79282737e-03],
#          ...,
#          [2.70299577e-03],
#          [2.69069281e-03],
#          [2.58150486e-03]],
#
#         [[2.76449981e-03],
#          [2.79282737e-03],
#          [2.79282737e-03],
#          ...,
#          [2.67492964e-03],
#          [2.65070819e-03],
#          [2.57622997e-03]],
#
#         [[2.77744867e-03],
#          [2.82073972e-03],
#          [2.77744867e-03],
#          ...,
#          [2.67531411e-03],
#          [2.66278047e-03],
#          [2.57566095e-03]],
#
#         ...,
#
#         [[3.12324952e-03],
#          [3.15116186e-03],
#          [3.10825529e-03],
#          ...,
#          [3.01521415e-03],
#          [2.96946251e-03],
#          [2.88538517e-03]],
#
#         [[3.17310727e-03],
#          [3.18784006e-03],
#          [3.17861284e-03],
#          ...,
#          [3.03059285e-03],
#          [3.00523337e-03],
#          [2.89841093e-03]],
#
#         [[3.16938562e-03],
#          [3.20014302e-03],
#          [3.20014302e-03],
#          ...,
#          [3.08603306e-03],
#          [3.02790158e-03],
#          [2.93103114e-03]]],
#
#
#        ...,
#
#
#        [[[1.32867161e-03],
#          [2.63808066e-03],
#          [3.51372090e-03],
#          ...,
#          [2.86867538e-03],
#          [2.84075808e-03],
#          [2.81672120e-03]],
#
#         [[9.84075902e-04],
#          [8.26327951e-04],
#          [1.36636941e-03],
#          ...,
#          [2.81530484e-03],
#          [2.71724414e-03],
#          [2.75135256e-03]],
#
#         [[7.58821686e-04],
#          [4.65231433e-04],
#          [1.01939594e-03],
#          ...,
#          [2.71013406e-03],
#          [2.81566628e-03],
#          [2.86616686e-03]],
#
#         ...,
#
#         [[2.74899346e-03],
#          [2.43786980e-03],
#          [2.27068512e-03],
#          ...,
#          [5.80101499e-04],
#          [5.84867359e-04],
#          [3.92244521e-04]],
#
#         [[2.66999948e-03],
#          [2.64084138e-03],
#          [2.24575471e-03],
#          ...,
#          [4.20353710e-04],
#          [5.43541715e-04],
#          [4.88758170e-04]],
#
#         [[2.74330950e-03],
#          [2.52209811e-03],
#          [2.25281129e-03],
#          ...,
#          [4.71707805e-04],
#          [4.38174548e-04],
#          [4.59102130e-04]]],
#
#
#        [[[3.56402307e-03],
#          [3.59238908e-03],
#          [3.63210458e-03],
#          ...,
#          [3.21229681e-03],
#          [3.18642215e-03],
#          [3.15105113e-03]],
#
#         [[3.51498039e-03],
#          [3.54756786e-03],
#          [3.58389235e-03],
#          ...,
#          [3.18715263e-03],
#          [3.18642215e-03],
#          [3.15105113e-03]],
#
#         [[3.50046290e-03],
#          [3.51522645e-03],
#          [3.56509189e-03],
#          ...,
#          [3.14528412e-03],
#          [3.12375394e-03],
#          [3.14489965e-03]],
#
#         ...,
#
#         [[3.66302549e-03],
#          [3.67590515e-03],
#          [3.74046597e-03],
#          ...,
#          [3.25465309e-03],
#          [3.16979931e-03],
#          [3.18463975e-03]],
#
#         [[3.66240677e-03],
#          [3.64571319e-03],
#          [3.70708189e-03],
#          ...,
#          [3.27422068e-03],
#          [3.17814225e-03],
#          [3.13390542e-03]],
#
#         [[3.62703576e-03],
#          [3.63164937e-03],
#          [3.68547482e-03],
#          ...,
#          [3.27349020e-03],
#          [3.20274817e-03],
#          [3.13200615e-03]]],
#
#
#        [[[3.29722414e-04],
#          [3.42240677e-04],
#          [3.45101115e-04],
#          ...,
#          [1.18943253e-03],
#          [1.21099423e-03],
#          [1.53340408e-03]],
#
#         [[3.29722414e-04],
#          [3.49068820e-04],
#          [3.29722414e-04],
#          ...,
#          [1.32085044e-03],
#          [1.25896194e-03],
#          [1.54343714e-03]],
#
#         [[3.29722414e-04],
#          [3.45101115e-04],
#          [3.45101115e-04],
#          ...,
#          [1.51752065e-03],
#          [1.38869200e-03],
#          [1.47316109e-03]],
#
#         ...,
#
#         [[3.45101115e-04],
#          [3.45101115e-04],
#          [3.45101115e-04],
#          ...,
#          [4.63547866e-04],
#          [4.48767920e-04],
#          [4.50386774e-04]],
#
#         [[3.45101115e-04],
#          [3.45101115e-04],
#          [3.45101115e-04],
#          ...,
#          [4.68494425e-04],
#          [4.50386774e-04],
#          [4.35008074e-04]],
#
#         [[3.45101115e-04],
#          [3.45101115e-04],
#          [3.32644368e-04],
#          ...,
#          [4.68494425e-04],
#          [4.50386774e-04],
#          [4.40267589e-04]]]])

# %%
LB = sk.preprocessing.LabelBinarizer()  #Initialize label binarizer
labelsCat = LB.fit_transform(labels)
labelsCat.shape
#labelsCat = to_categorical(labelsCat); print(labelsCat)
# Out:
# (5726, 9)

# %%
(X_train, X_test, Y_train, Y_test) = sk.model_selection.train_test_split(data, labelsCat,
    test_size=0.33, stratify=labels, random_state=42)
X_train
# Out:
# array([[[[1.44425410e-03],
#          [1.35018839e-03],
#          [1.30820915e-03],
#          ...,
#          [3.22562085e-03],
#          [3.19041215e-03],
#          [3.17479340e-03]],
#
#         [[1.41778239e-03],
#          [1.28439831e-03],
#          [1.20822376e-03],
#          ...,
#          [3.17646875e-03],
#          [3.17155786e-03],
#          [3.14864692e-03]],
#
#         [[1.34507574e-03],
#          [1.30030681e-03],
#          [1.14033064e-03],
#          ...,
#          [3.03773321e-03],
#          [3.03576136e-03],
#          [3.03607350e-03]],
#
#         ...,
#
#         [[2.88903345e-03],
#          [2.94170550e-03],
#          [2.92077124e-03],
#          ...,
#          [7.75066590e-04],
#          [1.00652757e-03],
#          [9.38646517e-04]],
#
#         [[2.88399923e-03],
#          [2.93167782e-03],
#          [2.95708420e-03],
#          ...,
#          [9.73621684e-04],
#          [1.04755709e-03],
#          [9.34043183e-04]],
#
#         [[2.85938485e-03],
#          [2.90917955e-03],
#          [2.90441215e-03],
#          ...,
#          [8.22119954e-04],
#          [1.01438985e-03],
#          [8.78442138e-04]]],
#
#
#        [[[1.65536640e-03],
#          [1.55536025e-03],
#          [1.63225375e-03],
#          ...,
#          [2.02378931e-03],
#          [1.71402537e-03],
#          [1.79532641e-03]],
#
#         [[1.60918570e-03],
#          [1.71108074e-03],
#          [1.69761323e-03],
#          ...,
#          [1.73299808e-03],
#          [1.97323183e-03],
#          [1.61220146e-03]],
#
#         [[1.47077739e-03],
#          [1.70270050e-03],
#          [1.80910880e-03],
#          ...,
#          [1.84308958e-03],
#          [1.87550173e-03],
#          [1.87932411e-03]],
#
#         ...,
#
#         [[7.32719723e-04],
#          [9.37610150e-04],
#          [8.51904652e-04],
#          ...,
#          [1.69984468e-03],
#          [1.89369012e-03],
#          [1.83279508e-03]],
#
#         [[9.05730104e-04],
#          [8.91474048e-04],
#          [9.05730104e-04],
#          ...,
#          [1.66908727e-03],
#          [1.66908727e-03],
#          [1.64949327e-03]],
#
#         [[8.10735871e-04],
#          [9.03030373e-04],
#          [8.72916571e-04],
#          ...,
#          [1.58579162e-03],
#          [1.65375317e-03],
#          [1.83060823e-03]]],
#
#
#        [[[2.07005342e-03],
#          [2.10194536e-03],
#          [2.12772011e-03],
#          ...,
#          [2.03101884e-03],
#          [1.98773236e-03],
#          [1.98299515e-03]],
#
#         [[2.04169459e-03],
#          [1.42564956e-03],
#          [1.09896194e-03],
#          ...,
#          [1.99553063e-03],
#          [1.96073818e-03],
#          [1.95460931e-03]],
#
#         [[2.10457516e-03],
#          [2.09150327e-03],
#          [2.09981057e-03],
#          ...,
#          [2.03123106e-03],
#          [2.03007766e-03],
#          [1.96847301e-03]],
#
#         ...,
#
#         [[4.69743099e-04],
#          [4.72906421e-04],
#          [4.47165244e-04],
#          ...,
#          [2.00540346e-03],
#          [1.78903037e-03],
#          [1.84771519e-03]],
#
#         [[5.45866974e-04],
#          [4.17508074e-04],
#          [3.61534933e-04],
#          ...,
#          [2.13765325e-03],
#          [1.95637134e-03],
#          [1.99182077e-03]],
#
#         [[5.22938124e-04],
#          [5.01010934e-04],
#          [5.16704368e-04],
#          ...,
#          [2.11836282e-03],
#          [2.20013348e-03],
#          [2.12114658e-03]]],
#
#
#        ...,
#
#
#        [[[1.93169396e-03],
#          [1.97353941e-03],
#          [1.91625682e-03],
#          ...,
#          [6.91469435e-04],
#          [6.84902730e-04],
#          [5.70362168e-04]],
#
#         [[1.97458977e-03],
#          [1.94707266e-03],
#          [1.95597386e-03],
#          ...,
#          [1.04699577e-03],
#          [1.16938716e-03],
#          [1.12348789e-03]],
#
#         [[1.96586697e-03],
#          [1.98897962e-03],
#          [2.01209227e-03],
#          ...,
#          [1.20504268e-03],
#          [1.54394771e-03],
#          [1.77078047e-03]],
#
#         ...,
#
#         [[3.40788158e-03],
#          [3.56202230e-03],
#          [3.69494195e-03],
#          ...,
#          [5.00370627e-04],
#          [3.95987697e-04],
#          [3.46583622e-04]],
#
#         [[3.45086659e-03],
#          [3.63336870e-03],
#          [3.68283122e-03],
#          ...,
#          [1.07414072e-04],
#          [2.00736640e-04],
#          [2.30296040e-04]],
#
#         [[3.68723875e-03],
#          [3.72569935e-03],
#          [3.69710111e-03],
#          ...,
#          [1.29476355e-04],
#          [9.10742022e-05],
#          [1.22792772e-04]]],
#
#
#        [[[2.03117133e-03],
#          [2.08399077e-03],
#          [2.05176624e-03],
#          ...,
#          [2.44283429e-03],
#          [2.47021464e-03],
#          [2.42407854e-03]],
#
#         [[2.03042215e-03],
#          [1.40514324e-03],
#          [1.16242281e-03],
#          ...,
#          [2.44537178e-03],
#          [2.40684814e-03],
#          [2.43101115e-03]],
#
#         [[2.01311599e-03],
#          [2.05060100e-03],
#          [2.07058070e-03],
#          ...,
#          [2.44251442e-03],
#          [2.42050334e-03],
#          [2.43398989e-03]],
#
#         ...,
#
#         [[1.07066259e-03],
#          [1.56710481e-03],
#          [2.85696209e-03],
#          ...,
#          [1.73747636e-03],
#          [1.73969396e-03],
#          [1.69741638e-03]],
#
#         [[1.15123113e-03],
#          [1.15541799e-03],
#          [1.18326968e-03],
#          ...,
#          [1.69738831e-03],
#          [1.70835986e-03],
#          [1.68093996e-03]],
#
#         [[1.13106498e-03],
#          [1.13106498e-03],
#          [1.10284506e-03],
#          ...,
#          [1.69298116e-03],
#          [1.66697885e-03],
#          [1.66665898e-03]]],
#
#
#        [[[3.23411532e-03],
#          [3.16409616e-03],
#          [3.33393772e-03],
#          ...,
#          [3.18136593e-03],
#          [2.96435967e-03],
#          [3.26509179e-03]],
#
#         [[3.24239306e-03],
#          [2.30412333e-03],
#          [3.30246021e-03],
#          ...,
#          [3.17774394e-03],
#          [3.02641173e-03],
#          [3.16284156e-03]],
#
#         [[3.05212222e-03],
#          [2.88041840e-03],
#          [2.47618008e-03],
#          ...,
#          [3.15523414e-03],
#          [3.18562468e-03],
#          [3.16875762e-03]],
#
#         ...,
#
#         [[2.83245113e-03],
#          [2.87482711e-03],
#          [2.93620915e-03],
#          ...,
#          [1.30457224e-03],
#          [1.24769988e-03],
#          [1.25323569e-03]],
#
#         [[2.85336482e-03],
#          [2.85277494e-03],
#          [2.90033932e-03],
#          ...,
#          [1.59736986e-03],
#          [1.50711226e-03],
#          [1.76315788e-03]],
#
#         [[2.85351861e-03],
#          [2.85935755e-03],
#          [2.95238331e-03],
#          ...,
#          [1.88499692e-03],
#          [1.96034679e-03],
#          [1.94329950e-03]]]])

# %%
Y_train.shape
# Out:
# (3836, 9)

# %%
datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)

# %%
batch_size = 8
epochs = 100
 
num_classes = 9

# %%
model = tf.keras.models.Sequential()

model.add(Conv2D(32, (3, 3), padding='same',input_shape=(100,100,1), name='conv1'))
model.add(Activation('relu', name='conv1_act'))
model.add(Conv2D(32, (3, 3), name='conv2'))
model.add(Activation('relu', name='conv2_act'))
model.add(MaxPooling2D(pool_size=(2, 2), name='pool1'))
model.add(Dropout(0.25, name='pool1_drop'))

model.add(Conv2D(64, (3, 3), padding='same', name='conv3'))
model.add(Activation('relu', name='conv3_act'))
model.add(Conv2D(64, (3, 3), name='conv4'))
model.add(Activation('relu', name='conv4_act'))
model.add(MaxPooling2D(pool_size=(2, 2), name='pool2'))
model.add(Dropout(0.25, name='pool2_drop'))

model.add(Flatten(name='flat1'))

model.add(Dense(512, name='fc5'))
model.add(Activation('relu', name='fc5_act'))
model.add(Dropout(0.5, name='fc5_drop'))
model.add(Dense(512, name='fc6'))
model.add(Activation('relu', name='fc6_act'))
model.add(Dropout(0.5, name='fc6_drop'))
model.add(Dense(num_classes, name='out'))
model.add(Activation('softmax', name='out_act'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1 (Conv2D)               (None, 100, 100, 32)      320
# _________________________________________________________________
# conv1_act (Activation)       (None, 100, 100, 32)      0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 98, 98, 32)        9248
# _________________________________________________________________
# conv2_act (Activation)       (None, 98, 98, 32)        0
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 49, 49, 32)        0
# _________________________________________________________________
# pool1_drop (Dropout)         (None, 49, 49, 32)        0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 49, 49, 64)        18496
# _________________________________________________________________
# conv3_act (Activation)       (None, 49, 49, 64)        0
# _________________________________________________________________
# conv4 (Conv2D)               (None, 47, 47, 64)        36928
# _________________________________________________________________
# conv4_act (Activation)       (None, 47, 47, 64)        0
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 23, 23, 64)        0
# _________________________________________________________________
# pool2_drop (Dropout)         (None, 23, 23, 64)        0
# _________________________________________________________________
# flat1 (Flatten)              (None, 33856)             0
# _________________________________________________________________
# fc5 (Dense)                  (None, 512)               17334784
# _________________________________________________________________
# fc5_act (Activation)         (None, 512)               0
# _________________________________________________________________
# fc5_drop (Dropout)           (None, 512)               0
# _________________________________________________________________
# fc6 (Dense)                  (None, 512)               262656
# _________________________________________________________________
# fc6_act (Activation)         (None, 512)               0
# _________________________________________________________________
# fc6_drop (Dropout)           (None, 512)               0
# _________________________________________________________________
# out (Dense)                  (None, 9)                 4617
# _________________________________________________________________
# out_act (Activation)         (None, 9)                 0
# =================================================================
# Total params: 17,667,049
# Trainable params: 17,667,049
# Non-trainable params: 0
# _________________________________________________________________

# %%
# initiate RMSprop optimizer
opt = tf.keras.optimizers.RMSprop(lr=0.0001, decay=1e-6)

# Compile classifier
model.compile(loss='categorical_crossentropy',
optimizer=opt,
metrics=['accuracy'])

# %%
with tf.device('/GPU:0'):
   R = model.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_test, Y_test), shuffle=True)
R
# Out:
# Train on 3836 samples, validate on 1890 samples
# Epoch 1/100
# 3836/3836 [==============================] - 13s 3ms/sample - loss: 2.0040 - accuracy: 0.3389 - val_loss: 2.0114 - val_accuracy: 0.3397
# Epoch 2/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 1.9832 - accuracy: 0.3394 - val_loss: 1.9821 - val_accuracy: 0.3397
# Epoch 3/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 1.9839 - accuracy: 0.3394 - val_loss: 1.9679 - val_accuracy: 0.3397
# Epoch 4/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 1.9746 - accuracy: 0.3394 - val_loss: 1.9891 - val_accuracy: 0.3397
# Epoch 5/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 1.9421 - accuracy: 0.3394 - val_loss: 1.9645 - val_accuracy: 0.3397
# Epoch 6/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 1.9122 - accuracy: 0.3392 - val_loss: 1.9189 - val_accuracy: 0.3397
# Epoch 7/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 1.8819 - accuracy: 0.3394 - val_loss: 1.9034 - val_accuracy: 0.3397
# Epoch 8/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 1.8517 - accuracy: 0.3399 - val_loss: 1.9254 - val_accuracy: 0.3704
# Epoch 9/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 1.8317 - accuracy: 0.3485 - val_loss: 1.8593 - val_accuracy: 0.3598
# Epoch 10/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 1.8097 - accuracy: 0.3647 - val_loss: 1.9683 - val_accuracy: 0.3709
# Epoch 11/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 1.7916 - accuracy: 0.3603 - val_loss: 1.9548 - val_accuracy: 0.3704
# Epoch 12/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 1.7749 - accuracy: 0.3702 - val_loss: 1.9485 - val_accuracy: 0.3820
# Epoch 13/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 1.7697 - accuracy: 0.3843 - val_loss: 2.0044 - val_accuracy: 0.3757
# Epoch 14/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 1.7555 - accuracy: 0.3837 - val_loss: 2.0079 - val_accuracy: 0.3937
# Epoch 15/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 1.7260 - accuracy: 0.3892 - val_loss: 1.9518 - val_accuracy: 0.3968
# Epoch 16/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 1.7127 - accuracy: 0.3908 - val_loss: 1.9727 - val_accuracy: 0.3873
# Epoch 17/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 1.7266 - accuracy: 0.3999 - val_loss: 1.9276 - val_accuracy: 0.4042
# Epoch 18/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 1.6957 - accuracy: 0.4051 - val_loss: 1.9381 - val_accuracy: 0.4069
# Epoch 19/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 1.7074 - accuracy: 0.4168 - val_loss: 1.9190 - val_accuracy: 0.4069
# Epoch 20/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 1.
100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 0.5616 - accuracy: 0.8074 - val_loss: 6.4778 - val_accuracy: 0.4889
# Epoch 84/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 0.5585 - accuracy: 0.8183 - val_loss: 5.0975 - val_accuracy: 0.4968
# Epoch 85/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 0.5539 - accuracy: 0.8243 - val_loss: 5.7804 - val_accuracy: 0.4873
# Epoch 86/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 0.5349 - accuracy: 0.8295 - val_loss: 5.7496 - val_accuracy: 0.5095
# Epoch 87/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 0.5246 - accuracy: 0.8277 - val_loss: 4.8844 - val_accuracy: 0.4878
# Epoch 88/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 0.5065 - accuracy: 0.8339 - val_loss: 4.3774 - val_accuracy: 0.5122
# Epoch 89/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 0.5121 - accuracy: 0.8412 - val_loss: 4.8171 - val_accuracy: 0.5138
# Epoch 90/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 0.4673 - accuracy: 0.8485 - val_loss: 4.0453 - val_accuracy: 0.5143
# Epoch 91/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 0.4590 - accuracy: 0.8540 - val_loss: 5.1862 - val_accuracy: 0.4910
# Epoch 92/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 0.4686 - accuracy: 0.8517 - val_loss: 4.5790 - val_accuracy: 0.5058
# Epoch 93/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 0.4676 - accuracy: 0.8493 - val_loss: 4.0985 - val_accuracy: 0.4672
# Epoch 94/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 0.4284 - accuracy: 0.8605 - val_loss: 5.6769 - val_accuracy: 0.5021
# Epoch 95/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 0.4437 - accuracy: 0.8650 - val_loss: 3.5819 - val_accuracy: 0.5048
# Epoch 96/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 0.4326 - accuracy: 0.8592 - val_loss: 3.1352 - val_accuracy: 0.4979
# Epoch 97/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 0.4171 - accuracy: 0.8678 - val_loss: 4.3071 - val_accuracy: 0.5101
# Epoch 98/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 0.4070 - accuracy: 0.8764 - val_loss: 4.7889 - val_accuracy: 0.5079
# Epoch 99/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 0.5162 - accuracy: 0.8689 - val_loss: 4.1693 - val_accuracy: 0.5085
# Epoch 100/100
# 3836/3836 [==============================] - 12s 3ms/sample - loss: 0.3911 - accuracy: 0.8783 - val_loss: 4.1945 - val_accuracy: 0.5111

# %%
import matplotlib.pyplot as plt
L = 5
W = 5
fig, axes = plt.subplots(L, W, figsize = (12, 12))
axes = axes.ravel()
y_pred = model.predict(X_test, batch_size=batch_size)
for i in np.arange(0,L*W):
    axes[i].imshow(X_test[i].reshape((100,100)),cmap='gray')
    axes[i].set_title('Prediction = {}\n True = {}'.format(y_pred.argmax(axis=1)[i], Y_test.argmax(axis=1)[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace = 1, hspace=1)

# %%
from sklearn.metrics import classification_report
y_pred0 = model.predict(X_test, batch_size=batch_size)
y_pred = np.argmax(y_pred0, axis=1)
print(classification_report(Y_test.argmax(axis=1), y_pred,target_names=LB.classes_))
# Out:
#                 precision    recall  f1-score   support
#
#        bicolor       0.40      0.26      0.32       148
#         calico       0.58      0.48      0.52       164
#       hairless       0.40      0.40      0.40       209
#    point_color       0.49      0.45      0.47       243
#    solid_color       0.67      0.71      0.69       642
#  tabby_classic       0.38      0.27      0.31       109
# tabby_mackerel       0.32      0.31      0.32       103
#  tabby_spotted       0.35      0.55      0.43       210
#  tortoiseshell       0.51      0.35      0.42        62
#
#       accuracy                           0.51      1890
#      macro avg       0.46      0.42      0.43      1890
#   weighted avg       0.51      0.51      0.51      1890

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test.argmax(axis=1),y_pred)
# Out:
# 0.5111111111111111

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(y_pred, Y_test.argmax(axis=1))
plt.figure(figsize = (10, 10))
sns.heatmap(cm, annot = True)

# %%
plt.plot(R.history['loss'], label='train loss')
plt.plot(R.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# plot the accuracy
plt.plot(R.history['accuracy'], label='train acc')
plt.plot(R.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
